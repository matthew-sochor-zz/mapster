# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 1
# %aimport mapster
from os import listdir
import pandas as pd
import time
import numpy as np
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
upper_right = (42.390609, -71.127139)
lower_left = (42.354473, -71.182877)
somerville_ll = (42.381903, -71.113967)
somerville_ur = (42.384740, -71.109665)
watertown = (42.374071, -71.156397)

#pizza = mapster.map_yelp(watertown,['pizza'])

# %%
somerville = mapster.map_area(somerville_ll,somerville_ur)

# %%
somerville
# Out:
#                                                         address        lat  \
# px      py
# 1268600 2643300     25 Hammond Street, Cambridge, MA 02138, USA  42.381119
#         2643325  45 Sacramento Street, Cambridge, MA 02138, USA  42.382704
#         2643350    66 Prentiss Street, Cambridge, MA 02140, USA  42.384289
# 1268625 2643300     90 Hammond Street, Cambridge, MA 02138, USA  42.381119
#         2643325  74 Sacramento Street, Cambridge, MA 02138, USA  42.382704
#         2643350     22 Miller Street, Somerville, MA 02143, USA  42.384289
# 1268650 2643300     138 Irving Street, Cambridge, MA 02138, USA  42.381119
#         2643325         8 Kent Court, Somerville, MA 02143, USA  42.382704
#         2643350     1 Belmont Street, Somerville, MA 02143, USA  42.384289
#
#                        lng
# px      py
# 1268600 2643300 -71.115189
#         2643325 -71.115189
#         2643350 -71.115189
# 1268625 2643300 -71.113043
#         2643325 -71.113043
# ...

# %%
yelp_map_somerville = mapster.map_yelp(somerville,['pizza','burger'])

# %%
ind = yelp_map_somerville.index
yelp_map_somerville.xs(ind[0][0:-1]).xs(ind[0][-1])['score'].std()
# Out:
# 6.7691664614879645

# %%
x = somerville.copy()

# %%
som = somerville.copy()
mapster.merge_yelp(som,yelp_map_somerville,mode='min')
som
# Out:
#                                                         address        lat  \
# px      py
# 1268600 2643300     25 Hammond Street, Cambridge, MA 02138, USA  42.381119
#         2643325  45 Sacramento Street, Cambridge, MA 02138, USA  42.382704
#         2643350    66 Prentiss Street, Cambridge, MA 02140, USA  42.384289
# 1268625 2643300     90 Hammond Street, Cambridge, MA 02138, USA  42.381119
#         2643325  74 Sacramento Street, Cambridge, MA 02138, USA  42.382704
#         2643350     22 Miller Street, Somerville, MA 02143, USA  42.384289
# 1268650 2643300     138 Irving Street, Cambridge, MA 02138, USA  42.381119
#         2643325         8 Kent Court, Somerville, MA 02143, USA  42.382704
#         2643350     1 Belmont Street, Somerville, MA 02143, USA  42.384289
#
#                        lng    pizza pizza-source     burger burger-source
# px      py
# 1268600 2643300 -71.115189  45.5000     yelp-min  20.816327      yelp-min
# ...

# %%
som_mean
# Out:
#                                                         address        lat  \
# px      py
# 1268600 2643300     25 Hammond Street, Cambridge, MA 02138, USA  42.381119
#         2643325  45 Sacramento Street, Cambridge, MA 02138, USA  42.382704
#         2643350    66 Prentiss Street, Cambridge, MA 02140, USA  42.384289
# 1268625 2643300     90 Hammond Street, Cambridge, MA 02138, USA  42.381119
#         2643325  74 Sacramento Street, Cambridge, MA 02138, USA  42.382704
#         2643350     22 Miller Street, Somerville, MA 02143, USA  42.384289
# 1268650 2643300     138 Irving Street, Cambridge, MA 02138, USA  42.381119
#         2643325         8 Kent Court, Somerville, MA 02143, USA  42.382704
#         2643350     1 Belmont Street, Somerville, MA 02143, USA  42.384289
#
#                        lng      pizza pizza-source     burger burger-source
# px      py
# 1268600 2643300 -71.115189  50.729167    yelp-mean  59.947279     yelp-mean
# ...

# %%
ind = somerville.index
somerville.xs(ind[0])
# Out:
# address    25 Hammond Street, Cambridge, MA 02138, USA
# lat                                           42.38112
# lng                                          -71.11519
# Name: (1268600.0, 2643300.0), dtype: object

# %%
yind = yelp_map_somerville.index
yelp_map_somerville.xs(yind[0][:-1]).xs(yind[0][-1])
# Out:
#                                                         address        lat  \
# px      py
# 1268600 2643300     25 Hammond Street, Cambridge, MA 02138, USA  42.381119
#         2643325  45 Sacramento Street, Cambridge, MA 02138, USA  42.382704
#         2643350    66 Prentiss Street, Cambridge, MA 02140, USA  42.384289
# 1268625 2643300     90 Hammond Street, Cambridge, MA 02138, USA  42.381119
#         2643325  74 Sacramento Street, Cambridge, MA 02138, USA  42.382704
#         2643350     22 Miller Street, Somerville, MA 02143, USA  42.384289
# 1268650 2643300     138 Irving Street, Cambridge, MA 02138, USA  42.381119
#         2643325         8 Kent Court, Somerville, MA 02143, USA  42.382704
#         2643350     1 Belmont Street, Somerville, MA 02143, USA  42.384289
#
#                        lng
# px      py
# 1268600 2643300 -71.115189
#         2643325 -71.115189
#         2643350 -71.115189
# 1268625 2643300 -71.113043
#         2643325 -71.113043
# ...

# %%
wmap = mapster.map_area(lower_left,upper_right)
# Out:
# Error: Geocoded address > 25.0% away from starting lat/lng
# Geocoding failed:
# ZERO_RESULTS
# Error: Geocoded address > 25.0% away from starting lat/lng
# Error: Geocoded address > 25.0% away from starting lat/lng
# Error: Geocoded address > 25.0% away from starting lat/lng
# Error: Geocoded address > 25.0% away from starting lat/lng
# Error: Geocoded address > 25.0% away from starting lat/lng
# Error: Geocoded address > 25.0% away from starting lat/lng
# Error: Geocoded address > 25.0% away from starting lat/lng
# Error: Geocoded address > 25.0% away from starting lat/lng
# Error: Geocoded address > 25.0% away from starting lat/lng
# Geocoding failed:
# ZERO_RESULTS
# Error: Geocoded address > 25.0% away from starting lat/lng
# Error: Geocoded address > 25.0% away from starting lat/lng
# Error: Geocoded address > 25.0% away from starting lat/lng
# Error: Geocoded address > 25.0% away from starting lat/lng
# Error: Geocoded address > 25.0% away from starting lat/lng
# ...

# %%
yelp_map_watertown = mapster.map_yelp(wmap,['pizza','burger'])
# Out:
# Exhausted distance matrix key: 0
# Exhausted distance matrix key: 1

# %%
watertown = wmap.copy()

# %%
mapster.merge_yelp(watertown,yelp_map_watertown,mode='min')

# %%
jamaica_plain_ll =(42.303269, -71.128043)
jamaica_plain_ur =(42.326522, -71.092777)
jamaica_plain = mapster.map_area(jamaica_plain_ll,jamaica_plain_ur)
yelp_map_jamaica_plain = mapster.map_yelp(jamaica_plain,['pizza','burger'])
mapster.merge_yelp(jamaica_plain,yelp_map_jamaica_plain,mode='min')
# Out:
# Error: Geocoded address > 25.0% away from starting lat/lng
# Error: Geocoded address > 25.0% away from starting lat/lng
# Error: Geocoded address > 25.0% away from starting lat/lng
# Error: Geocoded address > 25.0% away from starting lat/lng
# Error: Geocoded address > 25.0% away from starting lat/lng
# Error: Geocoded address > 25.0% away from starting lat/lng
# Error: Geocoded address > 25.0% away from starting lat/lng
# Error: Geocoded address > 25.0% away from starting lat/lng
# Error: Geocoded address > 25.0% away from starting lat/lng
# Error: Geocoded address > 25.0% away from starting lat/lng
# Error: Geocoded address > 25.0% away from starting lat/lng
# Error: Geocoded address > 25.0% away from starting lat/lng
# Error: Geocoded address > 25.0% away from starting lat/lng
# Error: Geocoded address > 25.0% away from starting lat/lng
# Error: Geocoded address > 25.0% away from starting lat/lng
# Error: Geocoded address > 25.0% away from starting lat/lng
# ...

# %%
jamaica_plain
# Out:
#                                                            address        lat  \
# px      py
# 1268450 2642050          1153 Centre Street, Boston, MA 02130, USA  42.301817
#         2642075  70 Westchester Road, Jamaica Plain, MA 02130, USA  42.303404
#         2642100      52 Louders Lane, Jamaica Plain, MA 02130, USA  42.304991
#         2642125         3 David Road, Jamaica Plain, MA 02130, USA  42.306578
#         2642150     4 Driftwood Road, Jamaica Plain, MA 02130, USA  42.308165
#         2642175      9 Woodland Road, Jamaica Plain, MA 02130, USA  42.309752
#         2642200      316 Pond Street, Jamaica Plain, MA 02130, USA  42.311339
#         2642225       16-38 Rockwood Street, Boston, MA 02130, USA  42.312926
#         2642250   65 Rockwood Street, Jamaica Plain, MA 02130, USA  42.314512
#         2642400        2-152 Codman Road, Brookline, MA 02445, USA  42.324032
#         2642425           77 Codman Road, Brookline, MA 02445, USA  42.325618
# ...

# %%
yelp_map_watertown_mexican = mapster.map_yelp(watertown,['mexican'])

# %%
yelp_map_jamaica_plain_mexican = mapster.map_yelp(jamaica_plain,['mexican'])
# Out:
# Yelp search failed for this location: The Hellenic University Foundation 222-258 Prince Street Jamaica Plain MA 02130 USA
# Oauth2 error on the following business: el-pelón-taquería-boston-3
# Oauth2 error on the following business: el-pelón-taquería-boston-3
# Oauth2 error on the following business: el-pelón-taquería-boston-3
# Oauth2 error on the following business: el-pelón-taquería-boston-3
# Oauth2 error on the following business: el-pelón-taquería-boston-3
# Oauth2 error on the following business: el-pelón-taquería-boston-3
# Oauth2 error on the following business: el-pelón-taquería-boston-3
# Oauth2 error on the following business: el-pelón-taquería-boston-3
# Oauth2 error on the following business: el-pelón-taquería-boston-3
# Oauth2 error on the following business: el-pelón-taquería-boston-3
# Oauth2 error on the following business: el-pelón-taquería-boston-3
# Oauth2 error on the following business: el-pelón-taquería-boston-3
# ...

# %%
mapster.score_map_yelp(jamaica_plain,yelp_map_jamaica_plain_mexican,mode='min')
jamaica_plain
# Out:
#                                                            address        lat  \
# px      py
# 1268450 2642050          1153 Centre Street, Boston, MA 02130, USA  42.301817
#         2642075  70 Westchester Road, Jamaica Plain, MA 02130, USA  42.303404
#         2642100      52 Louders Lane, Jamaica Plain, MA 02130, USA  42.304991
#         2642125         3 David Road, Jamaica Plain, MA 02130, USA  42.306578
#         2642150     4 Driftwood Road, Jamaica Plain, MA 02130, USA  42.308165
#         2642175      9 Woodland Road, Jamaica Plain, MA 02130, USA  42.309752
#         2642200      316 Pond Street, Jamaica Plain, MA 02130, USA  42.311339
#         2642225       16-38 Rockwood Street, Boston, MA 02130, USA  42.312926
#         2642250   65 Rockwood Street, Jamaica Plain, MA 02130, USA  42.314512
#         2642400        2-152 Codman Road, Brookline, MA 02445, USA  42.324032
#         2642425           77 Codman Road, Brookline, MA 02445, USA  42.325618
# ...

# %%
mapster.merge_yelp(watertown,yelp_map_watertown_mexican)
watertown
# Out:
#                                                            address        lat  \
# px      py
# 1267800 2642875       47-65 Eldredge Street, Newton, MA 02458, USA  42.354168
#         2642900        49-93 Baldwin Street, Newton, MA 02458, USA  42.355753
#         2642925  Centre Street & Interstate 90 & Washington Str...  42.357339
#         2642950         51 Jefferson Street, Newton, MA 02458, USA  42.358924
#         2642975           37 Hunt Street, Watertown, MA 02472, USA  42.360510
#         2643000            Nonantum Road, Watertown, MA 02472, USA  42.362096
#         2643025  13-29 Charles River Road, Watertown, MA 02472,...  42.363681
#         2643050      2-12 Arsenal Street, Watertown, MA 02472, USA  42.365267
#         2643075         40 Spring Street, Watertown, MA 02472, USA  42.366852
#         2643100      50-66 Church Street, Watertown, MA 02472, USA  42.368437
#         2643125       9 Hawthorne Street, Watertown, MA 02472, USA  42.370023
# ...

# %%
ymjp = yelp_map_jamaica_plain.copy()

# %%
ymjp_mex = yelp_map_jamaica_plain_mexican.copy()

# %%
ymjp = mapster.merge_map_yelp(ymjp,ymjp_mex)
ymjp
# Out:
#                         business lat business lng  \
# px      py      search
# 1268450 2642050 burger       42.2942    -71.13614
#                 burger       42.2873    -71.14904
#                 burger      42.31481    -71.11428
#                 mexican     42.29402    -71.13681
#                 mexican     42.28733    -71.15029
#                 mexican     42.31213    -71.11414
#                 pizza       42.30999    -71.11543
#                 pizza       42.31269    -71.11404
#                 pizza       42.29392    -71.13699
#         2642075 burger       42.2942    -71.13614
#                 burger      42.31481    -71.11428
#                 burger      42.31493    -71.11425
#                 mexican     42.29402    -71.13681
#                 mexican     42.31213    -71.11414
#                 mexican     42.28733    -71.15029
#                 pizza       42.30999    -71.11543
#                 pizza       42.31269    -71.11404
# ...

# %%
watertown
# Out:
#                                                            address        lat  \
# px      py
# 1267800 2642875       47-65 Eldredge Street, Newton, MA 02458, USA  42.354168
#         2642900        49-93 Baldwin Street, Newton, MA 02458, USA  42.355753
#         2642925  Centre Street & Interstate 90 & Washington Str...  42.357339
#         2642950         51 Jefferson Street, Newton, MA 02458, USA  42.358924
#         2642975           37 Hunt Street, Watertown, MA 02472, USA  42.360510
#         2643000            Nonantum Road, Watertown, MA 02472, USA  42.362096
#         2643025  13-29 Charles River Road, Watertown, MA 02472,...  42.363681
#         2643050      2-12 Arsenal Street, Watertown, MA 02472, USA  42.365267
#         2643075         40 Spring Street, Watertown, MA 02472, USA  42.366852
#         2643100      50-66 Church Street, Watertown, MA 02472, USA  42.368437
#         2643125       9 Hawthorne Street, Watertown, MA 02472, USA  42.370023
# ...

# %%
yelp_map_watertown = mapster.merge_map_yelp(yelp_map_watertown,yelp_map_watertown_mexican)
yelp_map_watertown
# Out:
#                          business lat  business lng  \
# px      py      search
# 1267800 2642875 burger      42.365387    -71.181725
#                 burger      42.357028    -71.186551
#                 burger      42.330911    -71.192151
#                 mexican     42.349787    -71.206843
#                 mexican     42.340224    -71.166502
#                 mexican     42.370487    -71.220790
#                 pizza       42.356998    -71.186836
#                 pizza       42.351168    -71.168334
#                 pizza       42.349387    -71.163766
#         2642900 burger      42.365387    -71.181725
#                 burger      42.357028    -71.186551
#                 burger      42.356789    -71.186531
#                 mexican     42.349787    -71.206843
#                 mexican     42.340224    -71.166502
#                 mexican     42.370487    -71.220790
#                 pizza       42.356998    -71.186836
#                 pizza       42.351168    -71.168334
# ...

# %%
yelp_map_watertown.to_pickle('map_yelp_watertown.pkl')

# %%
yelp_map_jamaica_plain = mapster.merge_map_yelp(yelp_map_jamaica_plain,yelp_map_jamaica_plain_mexican)
yelp_map_jamaica_plain
# Out:
#                         business lat business lng  \
# px      py      search
# 1268450 2642050 burger       42.2942    -71.13614
#                 burger       42.2873    -71.14904
#                 burger      42.31481    -71.11428
#                 mexican     42.29402    -71.13681
#                 mexican     42.28733    -71.15029
#                 mexican     42.31213    -71.11414
#                 pizza       42.30999    -71.11543
#                 pizza       42.31269    -71.11404
#                 pizza       42.29392    -71.13699
#         2642075 burger       42.2942    -71.13614
#                 burger      42.31481    -71.11428
#                 burger      42.31493    -71.11425
#                 mexican     42.29402    -71.13681
#                 mexican     42.31213    -71.11414
#                 mexican     42.28733    -71.15029
#                 pizza       42.30999    -71.11543
#                 pizza       42.31269    -71.11404
# ...

# %%
yelp_map_jamaica_plain.to_pickle('map_yelp_jamaica_plain.pkl')

# %%
jamaica_plain.to_pickle('jamaica_plain.pkl')

# %%
mapster.score_map_yelp(watertown,yelp_map_watertown,mode='min')
watertown
# Out:
#                                                            address        lat  \
# px      py
# 1267800 2642875       47-65 Eldredge Street, Newton, MA 02458, USA  42.354168
#         2642900        49-93 Baldwin Street, Newton, MA 02458, USA  42.355753
#         2642925  Centre Street & Interstate 90 & Washington Str...  42.357339
#         2642950         51 Jefferson Street, Newton, MA 02458, USA  42.358924
#         2642975           37 Hunt Street, Watertown, MA 02472, USA  42.360510
#         2643000            Nonantum Road, Watertown, MA 02472, USA  42.362096
#         2643025  13-29 Charles River Road, Watertown, MA 02472,...  42.363681
#         2643050      2-12 Arsenal Street, Watertown, MA 02472, USA  42.365267
#         2643075         40 Spring Street, Watertown, MA 02472, USA  42.366852
#         2643100      50-66 Church Street, Watertown, MA 02472, USA  42.368437
#         2643125       9 Hawthorne Street, Watertown, MA 02472, USA  42.370023
# ...

# %%
watertown.to_pickle('watertown.pkl')

# %%
yelp_map_watertown.to_pickle('./pickles/yelp_map_watertown.pkl')

# %%
yelp_map_jamaica_plain.to_pickle('./pickles/yelp_map_jamaica_plain.pkl')
