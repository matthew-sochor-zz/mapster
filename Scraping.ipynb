# %% [markdown]
# # March 15, 2015
#
# I currently have two maps started, Jamaica Plain and Watertown, but with pizza, mexican and burger searches.
#
# I'll start by importing them and then I'll just add searches
#
# ## Searches I want
# 1. Pizza
# 2. Burger
# 3. Mexican
# 4. Chinese
# 5. Thai
# 6. Diner
# 7. Indian
# 8.

# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 1
# %aimport mapster
from os import listdir
import pandas as pd
import time
import numpy as np

# %%
watertown = pd.read_pickle('./pickles/watertown.pkl')
watertown
# Out:
#                                                            address        lat  \
# px      py
# 1267800 2642875       47-65 Eldredge Street, Newton, MA 02458, USA  42.354168
#         2642900        49-93 Baldwin Street, Newton, MA 02458, USA  42.355753
#         2642925  Centre Street & Interstate 90 & Washington Str...  42.357339
#         2642950         51 Jefferson Street, Newton, MA 02458, USA  42.358924
#         2642975           37 Hunt Street, Watertown, MA 02472, USA  42.360510
#         2643000            Nonantum Road, Watertown, MA 02472, USA  42.362096
#         2643025  13-29 Charles River Road, Watertown, MA 02472,...  42.363681
#         2643050      2-12 Arsenal Street, Watertown, MA 02472, USA  42.365267
#         2643075         40 Spring Street, Watertown, MA 02472, USA  42.366852
#         2643100      50-66 Church Street, Watertown, MA 02472, USA  42.368437
#         2643125       9 Hawthorne Street, Watertown, MA 02472, USA  42.370023
# ...

# %%
searches = ['chinese','thai']#,'diner','indian','coffee']
map_yelp_watertown_3_15_2015 = mapster.map_yelp(watertown,searches)
# Out:
# Exhausted distance matrix key: 0
# Oauth2 error on the following business: o-yummy-cuisine-allston

# %%
map_yelp_watertown = pd.read_pickle('./pickles/yelp_map_watertown.pkl')
map_yelp_watertown
# Out:
#                          business lat  business lng  \
# px      py      search
# 1267800 2642875 burger      42.365387    -71.181725
#                 burger      42.357028    -71.186551
#                 burger      42.330911    -71.192151
#                 mexican     42.349787    -71.206843
#                 mexican     42.340224    -71.166502
#                 mexican     42.370487    -71.220790
#                 pizza       42.356998    -71.186836
#                 pizza       42.351168    -71.168334
#                 pizza       42.349387    -71.163766
#         2642900 burger      42.365387    -71.181725
#                 burger      42.357028    -71.186551
#                 burger      42.356789    -71.186531
#                 mexican     42.349787    -71.206843
#                 mexican     42.340224    -71.166502
#                 mexican     42.370487    -71.220790
#                 pizza       42.356998    -71.186836
#                 pizza       42.351168    -71.168334
# ...

# %%
map_yelp_watertown = mapster.merge_map_yelp(map_yelp_watertown,map_yelp_watertown_3_15_2015)
map_yelp_watertown
# Out:
#                          business lat  business lng  \
# px      py      search
# 1267800 2642875 burger      42.365387    -71.181725
#                 burger      42.357028    -71.186551
#                 burger      42.330911    -71.192151
#                 chinese     42.366224    -71.182322
#                 chinese     42.350328    -71.168994
#                 chinese     42.359762    -71.201943
#                 mexican     42.349787    -71.206843
#                 mexican     42.340224    -71.166502
#                 mexican     42.370487    -71.220790
#                 pizza       42.356998    -71.186836
#                 pizza       42.351168    -71.168334
#                 pizza       42.349387    -71.163766
#                 thai        42.357682    -71.184451
#                 thai        42.351182    -71.168462
#                 thai        42.366163    -71.185665
#         2642900 burger      42.365387    -71.181725
#                 burger      42.357028    -71.186551
# ...

# %%
map_yelp_watertown.to_pickle('./pickles/map_yelp_watertown.pkl')

# %%
mapster.score_map_yelp(watertown,map_yelp_watertown,mode='min')
watertown
# Out:
#                                                            address        lat  \
# px      py
# 1267800 2642875       47-65 Eldredge Street, Newton, MA 02458, USA  42.354168
#         2642900        49-93 Baldwin Street, Newton, MA 02458, USA  42.355753
#         2642925  Centre Street & Interstate 90 & Washington Str...  42.357339
#         2642950         51 Jefferson Street, Newton, MA 02458, USA  42.358924
#         2642975           37 Hunt Street, Watertown, MA 02472, USA  42.360510
#         2643000            Nonantum Road, Watertown, MA 02472, USA  42.362096
#         2643025  13-29 Charles River Road, Watertown, MA 02472,...  42.363681
#         2643050      2-12 Arsenal Street, Watertown, MA 02472, USA  42.365267
#         2643075         40 Spring Street, Watertown, MA 02472, USA  42.366852
#         2643100      50-66 Church Street, Watertown, MA 02472, USA  42.368437
#         2643125       9 Hawthorne Street, Watertown, MA 02472, USA  42.370023
# ...

# %%
watertown.to_pickle('./pickles/watertown.pkl')
x = pd.read_pickle('./pickles/watertown.pkl')
x
# Out:
#                                                            address        lat  \
# px      py
# 1267800 2642875       47-65 Eldredge Street, Newton, MA 02458, USA  42.354168
#         2642900        49-93 Baldwin Street, Newton, MA 02458, USA  42.355753
#         2642925  Centre Street & Interstate 90 & Washington Str...  42.357339
#         2642950         51 Jefferson Street, Newton, MA 02458, USA  42.358924
#         2642975           37 Hunt Street, Watertown, MA 02472, USA  42.360510
#         2643000            Nonantum Road, Watertown, MA 02472, USA  42.362096
#         2643025  13-29 Charles River Road, Watertown, MA 02472,...  42.363681
#         2643050      2-12 Arsenal Street, Watertown, MA 02472, USA  42.365267
#         2643075         40 Spring Street, Watertown, MA 02472, USA  42.366852
#         2643100      50-66 Church Street, Watertown, MA 02472, USA  42.368437
#         2643125       9 Hawthorne Street, Watertown, MA 02472, USA  42.370023
# ...

# %%
watertown = pd.read_pickle('./pickles/watertown.pkl')

# %%
searches = ['diner','indian','coffee']
map_yelp_watertown_3_16_2015 = mapster.map_yelp(watertown,searches)

# %%
if (1,23,4):
    print 'hello'
# Out:
# hello

# %%
map_yelp_watertown_3_16_2015_scored = mapster.map_yelp_travel_time(map_yelp_watertown_3_16_2015)
map_yelp_watertown_3_16_2015_scored
# Out:
# Exhausted distance matrix key: 0
# Exhausted distance matrix key: 1
# Exhausted distance matrix key: 1
# Exhausted distance matrix key: 1
# Exhausted distance matrix key: 1
# Exhausted distance matrix key: 1
# Exhausted distance matrix key: 1
# Exhausted distance matrix key: 1
# Exhausted distance matrix key: 1
# Exhausted distance matrix key: 1
# Exhausted distance matrix key: 1
# Exhausted distance matrix key: 1
# Exhausted distance matrix key: 1
# Exhausted distance matrix key: 1
# Exhausted distance matrix key: 1
# Exhausted distance matrix key: 1
# Exhausted distance matrix key: 1
# Exhausted distance matrix key: 1
# Exhausted distance matrix key: 1
# Exhausted distance matrix key: 1
# Exhausted distance matrix key: 2
# Exhausted distance matrix key: 2
# Exhausted distance matrix key: 2
# Exhausted distance matrix key: 2
# Exhausted distance matrix key: 2
#  Exhausted distance matrix key: 2Exhausted distance matrix key: 2
#
# ...

# %%
map_yelp_watertown = pd.read_pickle('./pickles/map_yelp_watertown.pkl')
map_yelp_watertown
# Out:
#                          business lat  business lng  \
# px      py      search
# 1267800 2642875 burger      42.365387    -71.181725
#                 burger      42.357028    -71.186551
#                 burger      42.330911    -71.192151
#                 chinese     42.366224    -71.182322
#                 chinese     42.350328    -71.168994
#                 chinese     42.359762    -71.201943
#                 mexican     42.349787    -71.206843
#                 mexican     42.340224    -71.166502
#                 mexican     42.370487    -71.220790
#                 pizza       42.356998    -71.186836
#                 pizza       42.351168    -71.168334
#                 pizza       42.349387    -71.163766
#                 thai        42.357682    -71.184451
#                 thai        42.351182    -71.168462
#                 thai        42.366163    -71.185665
#         2642900 burger      42.365387    -71.181725
#                 burger      42.357028    -71.186551
# ...

# %%
map_yelp_watertown = mapster.merge_map_yelp(map_yelp_watertown,map_yelp_watertown_3_16_2015_scored)
map_yelp_watertown
# Out:
#                          business lat  business lng  \
# px      py      search
# 1267800 2642875 burger      42.365387    -71.181725
#                 burger      42.357028    -71.186551
#                 burger      42.330911    -71.192151
#                 chinese     42.366224    -71.182322
#                 chinese     42.350328    -71.168994
#                 chinese     42.359762    -71.201943
#                 coffee      42.350086    -71.207062
#                 coffee            NaN           NaN
#                 coffee      42.341572    -71.154129
#                 diner       42.364784    -71.183205
#                 diner       42.363350    -71.172829
#                 diner       42.352662    -71.203009
#                 indian      42.354832    -71.144791
#                 indian      42.352732    -71.130435
#                 indian      42.370995    -71.158554
#                 mexican     42.349787    -71.206843
#                 mexican     42.340224    -71.166502
# ...

# %%
map_yelp_watertown.to_pickle('./pickles/map_yelp_watertown.pkl')

# %%
mapster.score_map_yelp(watertown,map_yelp_watertown,mode='min')
watertown
# Out:
#                                                            address        lat  \
# px      py
# 1267800 2642875       47-65 Eldredge Street, Newton, MA 02458, USA  42.354168
#         2642900        49-93 Baldwin Street, Newton, MA 02458, USA  42.355753
#         2642925  Centre Street & Interstate 90 & Washington Str...  42.357339
#         2642950         51 Jefferson Street, Newton, MA 02458, USA  42.358924
#         2642975           37 Hunt Street, Watertown, MA 02472, USA  42.360510
#         2643000            Nonantum Road, Watertown, MA 02472, USA  42.362096
#         2643025  13-29 Charles River Road, Watertown, MA 02472,...  42.363681
#         2643050      2-12 Arsenal Street, Watertown, MA 02472, USA  42.365267
#         2643075         40 Spring Street, Watertown, MA 02472, USA  42.366852
#         2643100      50-66 Church Street, Watertown, MA 02472, USA  42.368437
#         2643125       9 Hawthorne Street, Watertown, MA 02472, USA  42.370023
# ...

# %%
watertown.to_pickle('./pickles/watertown.pkl')

# %%
somerville_ll = (42.381903, -71.113967)
somerville_ur = (42.384740, -71.109665)

# %%
somerville = mapster.map_area(somerville_ll,somerville_ur)

# %%
businessDF = pd.read_pickle('./pickles/businessDF.pkl')
businessDF
# Out:
#                     changsho-cambridge  house-of-chang-cambridge  \
# business lat                  42.38353                  42.38361
# business lng                 -71.11989                 -71.13368
# business name                 Changsho            House of Chang
# error                            False                     False
# error-message                     None                      None
# id                  changsho-cambridge  house-of-chang-cambridge
# oauth2-ascii-error               False                     False
# rating                             3.5                         4
#
#                     zoes-chinese-restaurant-somerville  \
# business lat                                  42.38351
# business lng                                 -71.11316
# business name                 Zoe's Chinese Restaurant
# error                                            False
# error-message                                     None
# ...

# %%
test
# Out:
#                          business lat  business lng             business name  \
# px      py      search
# 1268600 2643300 chinese     42.383610    -71.133680            House of Chang
#                 chinese     42.383511    -71.113159  Zoe's Chinese Restaurant
#                 chinese     42.383530    -71.119888                  Changsho
#         2643325 chinese     42.383610    -71.133680            House of Chang
#                 chinese     42.383511    -71.113159  Zoe's Chinese Restaurant
#                 chinese     42.383530    -71.119888                  Changsho
#         2643350 chinese     42.383610    -71.133680            House of Chang
#                 chinese     42.383511    -71.113159  Zoe's Chinese Restaurant
#                 chinese     42.383530    -71.119888                  Changsho
# 1268625 2643300 chinese     42.383610    -71.133680            House of Chang
#                 chinese     42.383511    -71.113159  Zoe's Chinese Restaurant
# ...

# %%
test = mapster.map_yelp(somerville,['chinese'])

# %%
x = np.random.random(10)
x
# Out:
# array([ 0.42835415,  0.64398512,  0.06733561,  0.02415582,  0.06719862,
#         0.06156367,  0.83076125,  0.21996341,  0.24033178,  0.35282603])

# %%
group = 13
ind = 0
flag = True
while flag:
    if ind+group >= len(x):
        x_group = x[ind:]
        flag = False
    else:
        x_group = x[ind:ind+group]
    print x_group,ind,ind+group,len(x)
    ind += group
# Out:
# [ 0.42835415  0.64398512  0.06733561  0.02415582  0.06719862  0.06156367
#   0.83076125  0.21996341  0.24033178  0.35282603] 0 13 10

# %%
x[9:]
# Out:
# array([ 0.35282603])

# %%
mapster.test_key(5)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-134-8e6ed377c843> in <module>()
# ----> 1 mapster.test_key(5)
#
# /Users/matthewsochor/mapster/mapster.py in test_key(key)
#     108
#     109 def test_key(key):
# --> 110     return get_travel_time(42.381119, -71.115189, 42.383610, -71.133680,key=key)
#     111
#     112 def map_yelp_travel_time_inner(map_yelp_DF,key=None):
#
# /Users/matthewsochor/mapster/mapster.py in get_travel_time(orig_lat, orig_lng, dest_lat, dest_lng, mode, key)
#     454
#     455     #global distance_matrix_key
# --> 456     url = "https://maps.googleapis.com/maps/api/distancematrix/json?origins="+str(orig_lat)+","+str(orig_lng)+"&destinations="+str(dest_lat)+","+str(dest_lng)+"&mode="+mode+"&language=en-EN&sensor=false&key="+google_api_key[key]
#     457     try:
#     458         result= simplejson.load(urllib.urlopen(url))
#
# ...

# %%
test2 =mapster.map_yelp_travel_time(test)
test2
# Out:
# Exhausted distance matrix key: 0
# (0, 1391, 86.9375)
# (1, 342, 27.918367346938776)
# (3, 1430, 89.375)
# (5, 436, 35.591836734693878)
# (2, 500, 40.816326530612244)
# (4, 255, 20.816326530612244)
# (6, 1348, 84.25)
# (8, 395, 32.244897959183675)
# (9, 1507, 94.1875)
# (7, 153, 12.489795918367347)
# (11, 1272, 79.5)
# (10, 344, 28.081632653061224)
# (12, 1559, 97.4375)
# (14, 565, 46.122448979591837)
# (13, 130, 10.612244897959183)
# (17, 560, 45.714285714285715)
# (21, 1749, 109.3125)
# (16, 124, 10.122448979591837)
# (20, 1196, 74.75)
# (19, 349, 28.489795918367346)
# (18, 1630, 101.875)
# (26, 692, 56.489795918367349)
# (23, 765, 62.448979591836732)
# (24, 1797, 112.3125)
# (22, 294, 24.0)
# (25, 221, 18.040816326530614)
# (15, 1560, 97.5)
# ...

# %%
test2 =mapster.map_yelp_travel_time(test,group=5)
test2
# Out:
# Exhausted distance matrix key: 0
#                          business lat  business lng             business name  \
# px      py      search
# 1268600 2643300 chinese     42.383610    -71.133680            House of Chang
#                 chinese     42.383511    -71.113159  Zoe's Chinese Restaurant
#                 chinese     42.383530    -71.119888                  Changsho
#         2643325 chinese     42.383610    -71.133680            House of Chang
#                 chinese     42.383511    -71.113159  Zoe's Chinese Restaurant
#                 chinese     42.383530    -71.119888                  Changsho
#         2643350 chinese     42.383610    -71.133680            House of Chang
#                 chinese     42.383511    -71.113159  Zoe's Chinese Restaurant
#                 chinese     42.383530    -71.119888                  Changsho
# 1268625 2643300 chinese     42.383610    -71.133680            House of Chang
# ...

# %%
test2
# Out:
#                  py   search  business lat  business lng  \
#    px
# 0  1268600  2643300  chinese     42.383610    -71.133680
# 1  1268600  2643300  chinese     42.383511    -71.113159
# 2  1268600  2643300  chinese     42.383530    -71.119888
# 3  1268600  2643325  chinese     42.383610    -71.133680
# 4  1268600  2643325  chinese     42.383511    -71.113159
# 5  1268600  2643325  chinese     42.383530    -71.119888
# 6  1268600  2643350  chinese     42.383610    -71.133680
# 7  1268600  2643350  chinese     42.383511    -71.113159
# 8  1268600  2643350  chinese     42.383530    -71.119888
# 9  1268625  2643300  chinese     42.383610    -71.133680
# 10 1268625  2643300  chinese     42.383511    -71.113159
# 11 1268625  2643300  chinese     42.368802    -71.109780
# 12 1268625  2643325  chinese     42.383610    -71.133680
# 13 1268625  2643325  chinese     42.383511    -71.113159
# 14 1268625  2643325  chinese     42.383530    -71.119888
# ...

# %%
bus=df.loc[df.index[4]]
bus.empty
# Out:
# False

# %%
# %timeit out = mapster.travel_time_wrapper2(bus=df.loc[df.index[4]],key=1)
print out
# Out:
# 1 loops, best of 3: 186 ms per loop
# (4, 255, 20.816326530612244)

# %%
out = mapster.task_wrapper2(bus=df.loc[df.index[4]],key=1)
print out
# Out:
# (4, 255, 20.816326530612244)

# %%
df = test.reset_index()

df['ind'] = df.index
df
# Out:
#          px       py   search  business lat  business lng  \
# 0   1268600  2643300  chinese     42.383610    -71.133680
# 1   1268600  2643300  chinese     42.383511    -71.113159
# 2   1268600  2643300  chinese     42.383530    -71.119888
# 3   1268600  2643325  chinese     42.383610    -71.133680
# 4   1268600  2643325  chinese     42.383511    -71.113159
# 5   1268600  2643325  chinese     42.383530    -71.119888
# 6   1268600  2643350  chinese     42.383610    -71.133680
# 7   1268600  2643350  chinese     42.383511    -71.113159
# 8   1268600  2643350  chinese     42.383530    -71.119888
# 9   1268625  2643300  chinese     42.383610    -71.133680
# 10  1268625  2643300  chinese     42.383511    -71.113159
# 11  1268625  2643300  chinese     42.368802    -71.109780
# 12  1268625  2643325  chinese     42.383610    -71.133680
# 13  1268625  2643325  chinese     42.383511    -71.113159
# 14  1268625  2643325  chinese     42.383530    -71.119888
# ...

# %%
xxDF = xDF.sort(xDF.keys()[0])
xxxDF = xxDF.set_index(xxDF.keys()[0],name='ind')
xxxDF
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-116-b47216a80e82> in <module>()
#       1 xxDF = xDF.sort(xDF.keys()[0])
# ----> 2 xxxDF = xxDF.set_index(xxDF.keys()[0],name='ind')
#       3 xxxDF
#
# TypeError: set_index() got an unexpected keyword argument 'name'

# %%
df = test.reset_index()
df['ind'] = df.index
bus = []a
ind = df.index
bus = [(df.loc[i]['ind'],df.loc[i]['lat']) for i in df.index]
busses = [(df.loc[i]['ind'],df.loc[i]['lat'],df.loc[i]['lng'],df.loc[i]['business lat'],df.loc[i]['business lng'],df.loc[i]['rating'],df.loc[i]['error'],df.loc[i]['oauth2-ascii-error']) for i in df.index]
    
#print busses
#print mapster.travel_time_wrapper(busses[0])
q = mapster.score_yelp(test)
x = []
while not q.empty():
    x.append(q.get())

xDF = pd.DataFrame(x)
xx = xDF.set_index(xDF.keys()[0])
df['seconds'] = xx[xx.keys()[0]]
df['score'] = xx[xx.keys()[1]]
# Out:
#      0     1           2
# 0    1   342   27.918367
# 1    3  1430   89.375000
# 2    0  1391   86.937500
# 3    2   500   40.816327
# 4    6  1348   84.250000
# 5    4   255   20.816327
# 6    5   436   35.591837
# 7    7   153   12.489796
# 8    8   395   32.244898
# 9   10   344   28.081633
# 10  13   130   10.612245
# 11  12  1559   97.437500
# 12   9  1507   94.187500
# 13  16   124   10.122449
# 14  14   565   46.122449
# 15  15  1560   97.500000
# 16  11  1272   79.500000
# 17  17   560   45.714286
# 18  20  1196   74.750000
# 19  18  1630  101.875000
# 20  21  1749  109.312500
# 21  25   221   18.040816
# 22  19   349   28.489796
# 23  22   294   24.000000
# 24  23   765   62.448980
# 25  24  1797  112.312500
# 26  26   692   56.489796

# %%
xx = xDF.set_index(xDF.keys()[0])
df['seconds'] = xx[xx.keys()[0]]
df['score'] = xx[xx.keys()[1]]

# %%
df
# Out:
#          px       py   search  business lat  business lng  \
# 0   1268600  2643300  chinese     42.383610    -71.133680
# 1   1268600  2643300  chinese     42.383511    -71.113159
# 2   1268600  2643300  chinese     42.383530    -71.119888
# 3   1268600  2643325  chinese     42.383610    -71.133680
# 4   1268600  2643325  chinese     42.383511    -71.113159
# 5   1268600  2643325  chinese     42.383530    -71.119888
# 6   1268600  2643350  chinese     42.383610    -71.133680
# 7   1268600  2643350  chinese     42.383511    -71.113159
# 8   1268600  2643350  chinese     42.383530    -71.119888
# 9   1268625  2643300  chinese     42.383610    -71.133680
# 10  1268625  2643300  chinese     42.383511    -71.113159
# 11  1268625  2643300  chinese     42.368802    -71.109780
# 12  1268625  2643325  chinese     42.383610    -71.133680
# 13  1268625  2643325  chinese     42.383511    -71.113159
# 14  1268625  2643325  chinese     42.383530    -71.119888
# ...

# %%
x= {'a':1,'b':2}
xS = pd.Series(x)
xDF = pd.DataFrame([xS, xS, xS])
xDF
index = xDF.index
xSDF = xDF.xs(index[0])
type(xSDF)
xxDF = pd.DataFrame([xS, xSDF,xS,xSDF])
xxDF
# Out:
#            a  b
# Unnamed 0  1  2
# 0          1  2
# Unnamed 1  1  2
# 0          1  2

# %%
import requests

# %%
location = '40 Kimball Rd, Watertown MA'

# %%
print mapster.test_urllib(location)
# Out:
# {'status': 'OK', 'results': [{'geometry': {'location_type': 'RANGE_INTERPOLATED', 'bounds': {'northeast': {'lat': 42.3724419, 'lng': -71.15900409999999}, 'southwest': {'lat': 42.3724333, 'lng': -71.1590184}}, 'viewport': {'northeast': {'lat': 42.3737865802915, 'lng': -71.15766226970848}, 'southwest': {'lat': 42.3710886197085, 'lng': -71.1603602302915}}, 'location': {'lat': 42.3724333, 'lng': -71.1590184}}, 'address_components': [{'long_name': '40', 'types': ['street_number'], 'short_name': '40'}, {'long_name': 'Kimball Road', 'types': ['route'], 'short_name': 'Kimball Rd'}, {'long_name': 'Watertown', 'types': ['locality', 'political'], 'short_name': 'Watertown'}, {'long_name': 'Middlesex County', 'types': ['administrative_area_level_2', 'political'], 'short_name': 'Middlesex County'}, {'long_name': 'Massachusetts', 'types': ['administrative_area_level_1', 'political'], 'short_name': 'MA'}, {'long_name': 'United States', 'types': ['country', 'political'], 'short_name': 'US'}, {'long_n
# ...

# %%
print mapster.test_urllib2(location)
# Out:
# {'status': 'OK', 'results': [{'geometry': {'location_type': 'RANGE_INTERPOLATED', 'bounds': {'northeast': {'lat': 42.3724419, 'lng': -71.15900409999999}, 'southwest': {'lat': 42.3724333, 'lng': -71.1590184}}, 'viewport': {'northeast': {'lat': 42.3737865802915, 'lng': -71.15766226970848}, 'southwest': {'lat': 42.3710886197085, 'lng': -71.1603602302915}}, 'location': {'lat': 42.3724333, 'lng': -71.1590184}}, 'address_components': [{'long_name': '40', 'types': ['street_number'], 'short_name': '40'}, {'long_name': 'Kimball Road', 'types': ['route'], 'short_name': 'Kimball Rd'}, {'long_name': 'Watertown', 'types': ['locality', 'political'], 'short_name': 'Watertown'}, {'long_name': 'Middlesex County', 'types': ['administrative_area_level_2', 'political'], 'short_name': 'Middlesex County'}, {'long_name': 'Massachusetts', 'types': ['administrative_area_level_1', 'political'], 'short_name': 'MA'}, {'long_name': 'United States', 'types': ['country', 'political'], 'short_name': 'US'}, {'long_n
# ...

# %%
print mapster.test_request(location)
# Out:
# {u'status': u'OK', u'results': [{u'geometry': {u'location_type': u'RANGE_INTERPOLATED', u'bounds': {u'northeast': {u'lat': 42.3724419, u'lng': -71.15900409999999}, u'southwest': {u'lat': 42.3724333, u'lng': -71.1590184}}, u'viewport': {u'northeast': {u'lat': 42.3737865802915, u'lng': -71.15766226970848}, u'southwest': {u'lat': 42.3710886197085, u'lng': -71.1603602302915}}, u'location': {u'lat': 42.3724333, u'lng': -71.1590184}}, u'address_components': [{u'long_name': u'40', u'types': [u'street_number'], u'short_name': u'40'}, {u'long_name': u'Kimball Road', u'types': [u'route'], u'short_name': u'Kimball Rd'}, {u'long_name': u'Watertown', u'types': [u'locality', u'political'], u'short_name': u'Watertown'}, {u'long_name': u'Middlesex County', u'types': [u'administrative_area_level_2', u'political'], u'short_name': u'Middlesex County'}, {u'long_name': u'Massachusetts', u'types': [u'administrative_area_level_1', u'political'], u'short_name': u'MA'}, {u'long_name': u'United States', u'typ
# ...

# %%
# %timeit mapster.test_urllib(location)
# Out:
# 10 loops, best of 3: 174 ms per loop

# %%
# %timeit mapster.test_urllib2(location)
# Out:
# 10 loops, best of 3: 171 ms per loop

# %%
# %timeit mapster.test_request(location)
# Out:
# 10 loops, best of 3: 176 ms per loop
