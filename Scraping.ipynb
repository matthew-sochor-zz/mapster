# %% [markdown]
# # March 15, 2015
#
# I currently have two maps started, Jamaica Plain and Watertown, but with pizza, mexican and burger searches.
#
# I'll start by importing them and then I'll just add searches
#
# ## Searches I want
# 1. Pizza
# 2. Burger
# 3. Mexican
# 4. Chinese
# 5. Thai
# 6. Diner
# 7. Indian
# 8. Coffee

# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 1
# %aimport mapster
from os import listdir
import pandas as pd
import time
import numpy as np

# %%
watertown = pd.read_pickle('./pickles/watertown.pkl')
watertown.head()
# Out:
#         px       py                                            address  \
# 0  1267800  1551425       47-65 Eldredge Street, Newton, MA 02458, USA
# 1  1267800  1551400        49-93 Baldwin Street, Newton, MA 02458, USA
# 2  1267800  1551375  Centre Street & Interstate 90 & Washington Str...
# 3  1267800  1551350         51 Jefferson Street, Newton, MA 02458, USA
# 4  1267800  1551325           37 Hunt Street, Watertown, MA 02472, USA
#
#          lat        lng      pizza pizza-source   burger burger-source  \
# 0  42.354168 -71.183853  26.666667     yelp-min  33.8125      yelp-min
# 1  42.355753 -71.183853  18.814815     yelp-min  21.8125      yelp-min
# 2  42.357339 -71.183853  10.370370     yelp-min  11.1250      yelp-min
# 3  42.358924 -71.183853  13.728395     yelp-min  15.3750      yelp-min
# 4  42.360510 -71.183853  26.123457     yelp-min  31.0000      yelp-min
#
#     mexican    ...        thai  thai-source      coffee  coffee-source  \
# ...

# %%
jamaica_plain = pd.read_pickle('./pickles/jamaica_plain.pkl')
jamaica_plain.head()
# Out:
#         px       py                                            address  \
# 0  1268450  1552250          1153 Centre Street, Boston, MA 02130, USA
# 1  1268450  1552225  70 Westchester Road, Jamaica Plain, MA 02130, USA
# 2  1268450  1552200      52 Louders Lane, Jamaica Plain, MA 02130, USA
# 3  1268450  1552175         3 David Road, Jamaica Plain, MA 02130, USA
# 4  1268450  1552150     4 Driftwood Road, Jamaica Plain, MA 02130, USA
#
#          lat        lng      pizza pizza-source     burger burger-source  \
# 0  42.301817 -71.128063  75.673469     yelp-min  55.250000      yelp-min
# 1  42.303404 -71.128063  72.000000     yelp-min  67.187500      yelp-min
# 2  42.304991 -71.128063  57.937500     yelp-min  66.666667      yelp-min
# 3  42.306578 -71.128063  71.250000     yelp-min  67.456790      yelp-min
# 4  42.308165 -71.128063  76.750000     yelp-min  64.148148      yelp-min
#
#       mexican mexican-source     chinese chinese-source        thai  \
# ...

# %%
watertown.to_csv('./pickles/watertown.csv')
jamaica_plain.to_csv('./pickles/watertown.csv')

# %%
searches = ['chinese','thai']#,'diner','indian','coffee']
map_yelp_watertown_3_15_2015 = mapster.map_yelp(watertown,searches)
# Out:
# Exhausted distance matrix key: 0
# Oauth2 error on the following business: o-yummy-cuisine-allston

# %%
map_yelp_watertown = pd.read_pickle('./pickles/yelp_map_watertown.pkl')
map_yelp_watertown
# Out:
#                          business lat  business lng  \
# px      py      search
# 1267800 2642875 burger      42.365387    -71.181725
#                 burger      42.357028    -71.186551
#                 burger      42.330911    -71.192151
#                 mexican     42.349787    -71.206843
#                 mexican     42.340224    -71.166502
#                 mexican     42.370487    -71.220790
#                 pizza       42.356998    -71.186836
#                 pizza       42.351168    -71.168334
#                 pizza       42.349387    -71.163766
#         2642900 burger      42.365387    -71.181725
#                 burger      42.357028    -71.186551
#                 burger      42.356789    -71.186531
#                 mexican     42.349787    -71.206843
#                 mexican     42.340224    -71.166502
#                 mexican     42.370487    -71.220790
#                 pizza       42.356998    -71.186836
#                 pizza       42.351168    -71.168334
# ...

# %%
map_yelp_watertown = mapster.merge_map_yelp(map_yelp_watertown,map_yelp_watertown_3_15_2015)
map_yelp_watertown
# Out:
#                          business lat  business lng  \
# px      py      search
# 1267800 2642875 burger      42.365387    -71.181725
#                 burger      42.357028    -71.186551
#                 burger      42.330911    -71.192151
#                 chinese     42.366224    -71.182322
#                 chinese     42.350328    -71.168994
#                 chinese     42.359762    -71.201943
#                 mexican     42.349787    -71.206843
#                 mexican     42.340224    -71.166502
#                 mexican     42.370487    -71.220790
#                 pizza       42.356998    -71.186836
#                 pizza       42.351168    -71.168334
#                 pizza       42.349387    -71.163766
#                 thai        42.357682    -71.184451
#                 thai        42.351182    -71.168462
#                 thai        42.366163    -71.185665
#         2642900 burger      42.365387    -71.181725
#                 burger      42.357028    -71.186551
# ...

# %%
map_yelp_watertown.to_pickle('./pickles/map_yelp_watertown.pkl')

# %%
mapster.score_map_yelp(watertown,map_yelp_watertown,mode='min')
watertown
# Out:
#                                                            address        lat  \
# px      py
# 1267800 2642875       47-65 Eldredge Street, Newton, MA 02458, USA  42.354168
#         2642900        49-93 Baldwin Street, Newton, MA 02458, USA  42.355753
#         2642925  Centre Street & Interstate 90 & Washington Str...  42.357339
#         2642950         51 Jefferson Street, Newton, MA 02458, USA  42.358924
#         2642975           37 Hunt Street, Watertown, MA 02472, USA  42.360510
#         2643000            Nonantum Road, Watertown, MA 02472, USA  42.362096
#         2643025  13-29 Charles River Road, Watertown, MA 02472,...  42.363681
#         2643050      2-12 Arsenal Street, Watertown, MA 02472, USA  42.365267
#         2643075         40 Spring Street, Watertown, MA 02472, USA  42.366852
#         2643100      50-66 Church Street, Watertown, MA 02472, USA  42.368437
#         2643125       9 Hawthorne Street, Watertown, MA 02472, USA  42.370023
# ...

# %%
watertown.to_pickle('./pickles/watertown.pkl')
x = pd.read_pickle('./pickles/watertown.pkl')
x
# Out:
#                                                            address        lat  \
# px      py
# 1267800 2642875       47-65 Eldredge Street, Newton, MA 02458, USA  42.354168
#         2642900        49-93 Baldwin Street, Newton, MA 02458, USA  42.355753
#         2642925  Centre Street & Interstate 90 & Washington Str...  42.357339
#         2642950         51 Jefferson Street, Newton, MA 02458, USA  42.358924
#         2642975           37 Hunt Street, Watertown, MA 02472, USA  42.360510
#         2643000            Nonantum Road, Watertown, MA 02472, USA  42.362096
#         2643025  13-29 Charles River Road, Watertown, MA 02472,...  42.363681
#         2643050      2-12 Arsenal Street, Watertown, MA 02472, USA  42.365267
#         2643075         40 Spring Street, Watertown, MA 02472, USA  42.366852
#         2643100      50-66 Church Street, Watertown, MA 02472, USA  42.368437
#         2643125       9 Hawthorne Street, Watertown, MA 02472, USA  42.370023
# ...

# %%
watertown = pd.read_pickle('./pickles/watertown.pkl')

# %%
searches = ['diner','indian','coffee']
map_yelp_watertown_3_16_2015 = mapster.map_yelp(watertown,searches)

# %%
if (1,23,4):
    print 'hello'
# Out:
# hello

# %%
map_yelp_watertown_3_16_2015_scored = mapster.map_yelp_travel_time(map_yelp_watertown_3_16_2015)
map_yelp_watertown_3_16_2015_scored
# Out:
# Exhausted distance matrix key: 0
# Exhausted distance matrix key: 1
# Exhausted distance matrix key: 1
# Exhausted distance matrix key: 1
# Exhausted distance matrix key: 1
# Exhausted distance matrix key: 1
# Exhausted distance matrix key: 1
# Exhausted distance matrix key: 1
# Exhausted distance matrix key: 1
# Exhausted distance matrix key: 1
# Exhausted distance matrix key: 1
# Exhausted distance matrix key: 1
# Exhausted distance matrix key: 1
# Exhausted distance matrix key: 1
# Exhausted distance matrix key: 1
# Exhausted distance matrix key: 1
# Exhausted distance matrix key: 1
# Exhausted distance matrix key: 1
# Exhausted distance matrix key: 1
# Exhausted distance matrix key: 1
# Exhausted distance matrix key: 2
# Exhausted distance matrix key: 2
# Exhausted distance matrix key: 2
# Exhausted distance matrix key: 2
# Exhausted distance matrix key: 2
#  Exhausted distance matrix key: 2Exhausted distance matrix key: 2
#
# ...

# %%
map_yelp_watertown = pd.read_pickle('./pickles/map_yelp_watertown.pkl')
map_yelp_watertown
# Out:
#                          business lat  business lng  \
# px      py      search
# 1267800 2642875 burger      42.365387    -71.181725
#                 burger      42.357028    -71.186551
#                 burger      42.330911    -71.192151
#                 chinese     42.366224    -71.182322
#                 chinese     42.350328    -71.168994
#                 chinese     42.359762    -71.201943
#                 mexican     42.349787    -71.206843
#                 mexican     42.340224    -71.166502
#                 mexican     42.370487    -71.220790
#                 pizza       42.356998    -71.186836
#                 pizza       42.351168    -71.168334
#                 pizza       42.349387    -71.163766
#                 thai        42.357682    -71.184451
#                 thai        42.351182    -71.168462
#                 thai        42.366163    -71.185665
#         2642900 burger      42.365387    -71.181725
#                 burger      42.357028    -71.186551
# ...

# %%
map_yelp_watertown = mapster.merge_map_yelp(map_yelp_watertown,map_yelp_watertown_3_16_2015_scored)
map_yelp_watertown
# Out:
#                          business lat  business lng  \
# px      py      search
# 1267800 2642875 burger      42.365387    -71.181725
#                 burger      42.357028    -71.186551
#                 burger      42.330911    -71.192151
#                 chinese     42.366224    -71.182322
#                 chinese     42.350328    -71.168994
#                 chinese     42.359762    -71.201943
#                 coffee      42.350086    -71.207062
#                 coffee            NaN           NaN
#                 coffee      42.341572    -71.154129
#                 diner       42.364784    -71.183205
#                 diner       42.363350    -71.172829
#                 diner       42.352662    -71.203009
#                 indian      42.354832    -71.144791
#                 indian      42.352732    -71.130435
#                 indian      42.370995    -71.158554
#                 mexican     42.349787    -71.206843
#                 mexican     42.340224    -71.166502
# ...

# %%
map_yelp_watertown.to_pickle('./pickles/map_yelp_watertown.pkl')

# %%
mapster.score_map_yelp(watertown,map_yelp_watertown,mode='min')
watertown
# Out:
#                                                            address        lat  \
# px      py
# 1267800 2642875       47-65 Eldredge Street, Newton, MA 02458, USA  42.354168
#         2642900        49-93 Baldwin Street, Newton, MA 02458, USA  42.355753
#         2642925  Centre Street & Interstate 90 & Washington Str...  42.357339
#         2642950         51 Jefferson Street, Newton, MA 02458, USA  42.358924
#         2642975           37 Hunt Street, Watertown, MA 02472, USA  42.360510
#         2643000            Nonantum Road, Watertown, MA 02472, USA  42.362096
#         2643025  13-29 Charles River Road, Watertown, MA 02472,...  42.363681
#         2643050      2-12 Arsenal Street, Watertown, MA 02472, USA  42.365267
#         2643075         40 Spring Street, Watertown, MA 02472, USA  42.366852
#         2643100      50-66 Church Street, Watertown, MA 02472, USA  42.368437
#         2643125       9 Hawthorne Street, Watertown, MA 02472, USA  42.370023
# ...

# %%
watertown.to_pickle('./pickles/watertown.pkl')

# %%
somerville_ll = (42.381903, -71.113967)
somerville_ur = (42.384740, -71.109665)

# %%
somerville = mapster.map_area(somerville_ll,somerville_ur)

# %%
businessDF = pd.read_pickle('./pickles/businessDF.pkl')
businessDF
# Out:
#                     changsho-cambridge  house-of-chang-cambridge  \
# business lat                  42.38353                  42.38361
# business lng                 -71.11989                 -71.13368
# business name                 Changsho            House of Chang
# error                            False                     False
# error-message                     None                      None
# id                  changsho-cambridge  house-of-chang-cambridge
# oauth2-ascii-error               False                     False
# rating                             3.5                         4
#
#                     zoes-chinese-restaurant-somerville  \
# business lat                                  42.38351
# business lng                                 -71.11316
# business name                 Zoe's Chinese Restaurant
# error                                            False
# error-message                                     None
# ...

# %%
test
# Out:
#                          business lat  business lng             business name  \
# px      py      search
# 1268600 2643300 chinese     42.383610    -71.133680            House of Chang
#                 chinese     42.383511    -71.113159  Zoe's Chinese Restaurant
#                 chinese     42.383530    -71.119888                  Changsho
#         2643325 chinese     42.383610    -71.133680            House of Chang
#                 chinese     42.383511    -71.113159  Zoe's Chinese Restaurant
#                 chinese     42.383530    -71.119888                  Changsho
#         2643350 chinese     42.383610    -71.133680            House of Chang
#                 chinese     42.383511    -71.113159  Zoe's Chinese Restaurant
#                 chinese     42.383530    -71.119888                  Changsho
# 1268625 2643300 chinese     42.383610    -71.133680            House of Chang
#                 chinese     42.383511    -71.113159  Zoe's Chinese Restaurant
# ...

# %%
test = mapster.map_yelp(somerville,['chinese'])

# %%
test2 =mapster.map_yelp_travel_time(test,group=5)
test2
# Out:
# Exhausted distance matrix key: 0
#                          business lat  business lng             business name  \
# px      py      search
# 1268600 2643300 chinese     42.383610    -71.133680            House of Chang
#                 chinese     42.383511    -71.113159  Zoe's Chinese Restaurant
#                 chinese     42.383530    -71.119888                  Changsho
#         2643325 chinese     42.383610    -71.133680            House of Chang
#                 chinese     42.383511    -71.113159  Zoe's Chinese Restaurant
#                 chinese     42.383530    -71.119888                  Changsho
#         2643350 chinese     42.383610    -71.133680            House of Chang
#                 chinese     42.383511    -71.113159  Zoe's Chinese Restaurant
#                 chinese     42.383530    -71.119888                  Changsho
# 1268625 2643300 chinese     42.383610    -71.133680            House of Chang
# ...

# %%
print watertown.keys()
# Out:
# Index([u'address', u'lat', u'lng', u'pizza', u'pizza-source', u'burger', u'burger-source', u'mexican', u'mexican-source', u'chinese', u'chinese-source', u'thai', u'thai-source', u'coffee', u'coffee-source', u'diner', u'diner-source', u'indian', u'indian-source'], dtype='object')

# %% [markdown]
# ## Searches I want
# 1. Pizza
# 2. Burger
# 3. Mexican
# 4. Chinese
# 5. Thai
# 6. Diner
# 7. Indian
# 8. Coffee
#
# ## Searches done for Watertown
# 1. Pizza
# 2. Burger
# 3. Mexican
# 4. chinese
# 5. Thai
# 6. Coffee
# 7. Diner
# 8. Indian

# %%
map_yelp_jamaica_plain = pd.read_pickle('./pickles/map_yelp_jamaica_plain.pkl')
jamaica_plain = pd.read_pickle('./pickles/jamaica_plain.pkl')

# %%
print jamaica_plain.keys()
# Out:
# Index([u'address', u'lat', u'lng', u'pizza', u'pizza-source', u'burger', u'burger-source', u'mexican', u'mexican-source'], dtype='object')

# %% [markdown]
# ## searches done for Jamaica Plain
# 1. Pizza
# 2. Burger
# 3. Mexican

# %%
map_yelp_jp_3_23_2015 = mapster.map_yelp(jamaica_plain,['chinese'])
map_yelp_jp_3_23_2015
# Out:
# Adding new business: seven-star-street-bistro-roslindale
# Adding new business: mandarin-gourmet-chestnut-hill
# Adding new business: jp-kitchen-jamaica-plain
# Adding new business: kamado-super-fusion-jamaica-plain-2
# Adding new business: food-wall-chinese-restaurant-jamaica-plain
# Adding new business: sichuan-garden-brookline
# Adding new business: golden-temple-brookline
# Yelp search failed for this location: The Hellenic University Foundation 222-258 Prince Street Jamaica Plain MA 02130 USA
# Adding new business: wok-n-talk-jamaica-plain
# Adding new business: oriental-pearl-brookline
# Adding new business: lucky-boston-chinese-restaurant-roxbury
# Adding new business: oriental-house-chinese-restaurant-jamaica-plain
# Adding new business: yong-hon-restaurant-dorchester-center
# Adding new business: burritos-pizzeria-jamaica-plain
# Adding new business: roka-boston
# Exhausted distance matrix key: 0
# Exhausted distance matrix key: 1
# Exhausted distance matrix key: 2
# ...

# %%
map_yelp_jamaica_plain = mapster.merge_map_yelp(map_yelp_jamaica_plain,map_yelp_jp_3_23_2015)
map_yelp_jamaica_plain.to_pickle('./pickles/map_yelp_jamaica_plain.pkl')

# %%
mapster.score_map_yelp(jamaica_plain,map_yelp_jamaica_plain,mode='min')
jamaica_plain.to_pickle('./pickles/jamaica_plain.pkl')

# %%
print jamaica_plain.keys()
# Out:
# Index([u'address', u'lat', u'lng', u'pizza', u'pizza-source', u'burger', u'burger-source', u'mexican', u'mexican-source', u'chinese', u'chinese-source'], dtype='object')

# %% [markdown]
# ## searches done for Jamaica Plain
# 1. Pizza
# 2. Burger
# 3. Mexican
# 4. Chinese
#
# ## adding search
# Thai

# %%
map_yelp_jp_thai = mapster.map_yelp(jamaica_plain,['thai'])
map_yelp_jp_thai
# Out:
# Adding new business: wonder-spice-cafe-jamaica-plain
# Adding new business: noodle-barn-jamaica-plain
# Adding new business: thai-spice-west-roxbury
# Adding new business: pon-thai-bistro-brookline
# Adding new business: rod-dee-thai-brookline
# Adding new business: dok-bua-thai-kitchen-brookline
# Yelp search failed for this location: The Hellenic University Foundation 222-258 Prince Street Jamaica Plain MA 02130 USA
# Adding new business: rod-dee-thai-2-boston
# Adding new business: thaitation-boston
# Adding new business: pho-basil-boston
# Exhausted distance matrix key: 0
# Exhausted distance matrix key: 1
# Exhausted distance matrix key: 2
#                        business lat business lng         business name  error  \
# px      py      search
# 1268450 2642050 thai       42.31182    -71.11454     Wonder Spice Cafe  False
#                 thai       42.31145    -71.11466           Noodle Barn  False
# ...

# %%
map_yelp_jamaica_plain = mapster.merge_map_yelp(map_yelp_jamaica_plain,map_yelp_jp_thai)
map_yelp_jamaica_plain.to_pickle('./pickles/map_yelp_jamaica_plain.pkl')
mapster.score_map_yelp(jamaica_plain,map_yelp_jamaica_plain,mode='min')
jamaica_plain.to_pickle('./pickles/jamaica_plain.pkl')

# %%
print jamaica_plain.keys()
# Out:
# Index([u'address', u'lat', u'lng', u'pizza', u'pizza-source', u'burger', u'burger-source', u'mexican', u'mexican-source', u'chinese', u'chinese-source', u'thai', u'thai-source'], dtype='object')

# %% [markdown]
# # NOTE: stopped here 3/23/2015. Ran out of keys
#
# ## searches done for Jamaica Plain
# 1. Pizza
# 2. Burger
# 3. Mexican
# 4. Chinese
# 5. Thai
#
# ## adding search
# Coffee
#
# ## pending
# diner
# indian

# %%
map_yelp_jp = mapster.map_yelp(jamaica_plain,['coffee'])
map_yelp_jp

# %%
map_yelp_jamaica_plain = mapster.merge_map_yelp(map_yelp_jamaica_plain,map_yelp_jp)
map_yelp_jamaica_plain.to_pickle('./pickles/map_yelp_jamaica_plain.pkl')
mapster.score_map_yelp(jamaica_plain,map_yelp_jamaica_plain,mode='min')
jamaica_plain.to_pickle('./pickles/jamaica_plain.pkl')

# %% [markdown]
# # 4/6/2014
#
# Want to make a new map which fills in the current maps (watertown and jamaica plain).
#
# Then do the searches.
#
# I wrote a new merging tool: map_yelp_unique

# %%
ul = [max(watertown['lat']), min(watertown['lng'])]
lr = [min(jamaica_plain['lat']), max(jamaica_plain['lng'])]

# %%
watertown_jp = mapster.map_area(ul,lr)
# Out:
# Error: Geocoded address > 25.0% away from starting lat/lng
# Error: Geocoded address > 25.0% away from starting lat/lng
# Error: Geocoded address > 25.0% away from starting lat/lng
# Error: Geocoded address > 25.0% away from starting lat/lng
# Error: Geocoded address > 25.0% away from starting lat/lng
# Error: Geocoded address > 25.0% away from starting lat/lng
# Error: Geocoded address > 25.0% away from starting lat/lng
# Error: Geocoded address > 25.0% away from starting lat/lng
# Error: Geocoded address > 25.0% away from starting lat/lng
# Error: Geocoded address > 25.0% away from starting lat/lng
# Error: Geocoded address > 25.0% away from starting lat/lng
# Error: Geocoded address > 25.0% away from starting lat/lng
# Error: Geocoded address > 25.0% away from starting lat/lng
# Error: Geocoded address > 25.0% away from starting lat/lng
# Error: Geocoded address > 25.0% away from starting lat/lng
# Error: Geocoded address > 25.0% away from starting lat/lng
# ...

# %%
watertown_jp_nowater = mapster.map_yelp_unique(watertown_jp,watertown)

# %%
watertown_jp_nowater_nojp = mapster.map_yelp_unique(watertown_jp_nowater,jamaica_plain)

# %%
watertown_jp_nowater_nojp.to_pickle('./pickles/outside_watertown_jamaica_plain.pkl')

# %%
map_yelp_outside = mapster.map_yelp(watertown_jp_nowater_nojp,'burger')
# Out:
# Adding new business: wild-willys-burgers-watertown
# Adding new business: halfway-cafe-watertown
# Adding new business: strip-ts-restaurant-watertown
# Adding new business: buffs-pub-newton
# Adding new business: lees-burger-place-newton
# Adding new business: johnnys-luncheonette-newton
# Adding new business: shake-shack-chestnut-hill
# Adding new business: o-haras-food-and-spirits-newton-highlands
# Adding new business: porter-cafe-west-roxbury
# Adding new business: the-cottage-chestnut-hill-chestnut-hill
# Adding new business: the-real-deal-west-roxbury
# Adding new business: eagles-deli-brighton
# Adding new business: celebrity-pizza-and-dairy-bar-watertown
# Adding new business: the-proper-slice-brighton
# Adding new business: aquitaine-chestnut-hill-chestnut-hill
# Adding new business: roast-beast-boston
# Adding new business: the-glenville-stops-boston
# Yelp search failed for this location: Boston College Boston College - Brighton Campus 9 Lake Street Boston MA 02135 USA
# ...

# %%
mapster.score_map_yelp(watertown_jp_nowater_nojp,map_yelp_outside)

# %%
watertown_jp_nowater_nojp.tail()
# Out:
#                                               address        lat        lng  \
# 1828  1285-1329 Tremont Street, Boston, MA 02120, USA  42.332217 -71.093731
# 1829   265-273 Roxbury Street, Roxbury, MA 02119, USA  42.330631 -71.093731
# 1830        26 Linwood Square, Roxbury, MA 02119, USA  42.329045 -71.093731
# 1831         117 Cedar Street, Roxbury, MA 02119, USA  42.327458 -71.093731
# 1842             Pierpont Road, Boston, MA 02121, USA  42.306832 -71.093731
#
#            px       py    tx    ty  zoom      burger
# 1828  1268850  1551775  4956  6061    14   71.428571
# 1829  1268850  1551800  4956  6061    14   74.530612
# 1830  1268850  1551825  4956  6061    14  102.367347
# 1831  1268850  1551850  4956  6061    14   79.755102
# 1842  1268850  1552175  4956  6063    14   82.612245

# %%
watertown_jp_nowater_nojp.to_pickle('./pickles/outside_watertown_jamaica_plain.pkl')
map_yelp_outside.to_pickle('./pickles/map_yelp_outside_watertown_jamaica_plain.pkl')

# %% [markdown]
# # 4 -7 -2014
#
# picking up where we left off

# %%
outer = pd.read_pickle('./pickles/outside_watertown_jamaica_plain.pkl')
map_yelp_outer = pd.read_pickle('./pickles/map_yelp_outside_watertown_jamaica_plain.pkl')

# %%
map_yelp_outer2 = mapster.map_yelp(outer,'chinese')
# Out:
# Adding new business: wonder-cafe-watertown
# Adding new business: asiana-fusion-watertown-2
# Adding new business: shangri-la-belmont
# Adding new business: new-hong-kong-brighton
# Adding new business: ginger-root-chinese-cuisine-newton-2
# Adding new business: no1-noodle-house-newton
# Adding new business: rice-valley-newton
# Adding new business: jumbo-seafood-newton
# Adding new business: sichuan-gourmet-house-newton-highlands
# Adding new business: bernards-chestnut-hill
# Adding new business: fortune-panda-newton
# Adding new business: china-rainbow-watertown
# Adding new business: changs-house-brighton
# Adding new business: golden-garden-belmont
# Adding new business: shanghai-gate-allston
# Adding new business: west-garden-west-roxbury
# Adding new business: grasshopper-restaurant-allston
# Adding new business: the-green-peapod-watertown
# Adding new business: o-yummy-cuisine-allston
# ...

# %%
map_yelp_outer3 = mapster.merge_map_yelp(map_yelp_outer,map_yelp_outer2)
map_yelp_outer3.tail()
# Out:
#      business lat business lng                                 business name  \
# 3550     42.31436    -71.10414  Bella Luna Restaurant & The Milky Way Lounge
# 3551     42.30598    -71.08035                                   Burger King
# 3549     42.31522     -71.0988               Lucky Boston Chinese Restaurant
# 3550      42.3058    -71.10781                                    JP Kitchen
# 3551     42.29834    -71.08658                           Yong Hon Restaurant
#
#       error error-message                                       id        lat  \
# 3550  False          None                                Unnamed 0  42.306832
# 3551  False          None                                Unnamed 1  42.306832
# 3549  False          None  lucky-boston-chinese-restaurant-roxbury  42.306832
# 3550  False          None                 jp-kitchen-jamaica-plain  42.306832
# 3551  False          None    yong-hon-restaurant-dorchester-center  42.306832
#
# ...

# %%
mapster.score_map_yelp(wa

# %%
watertown_jp_nowater_nojp.to_pickle('./pickles/outside_watertown_jamaica_plain.pkl')
map_yelp_outer3.to_pickle('./pickles/map_yelp_outside_watertown_jamaica_plain.pkl')

# %% [markdown]
# # starting here 4/19/2015
#
# got chinese done.  maybe can get 3 done.

# %%
outer = pd.read_pickle('./pickles/outside_watertown_jamaica_plain.pkl')
map_yelp_outer = pd.read_pickle('./pickles/map_yelp_outside_watertown_jamaica_plain.pkl')

# %%
map_yelp_outer2 = mapster.map_yelp(outer,['chinese'])
# Out:
# Yelp search failed for this location: Boston College Boston College - Brighton Campus 9 Lake Street Boston MA 02135 USA
# Yelp search failed for this location: Boston College Boston College - Brighton Campus 2119-2163 Highway 30 Boston MA 02135 USA
# Yelp search failed for this location: Boston College Boston College - Brighton Campus Blessed Peter Faber Jesuit Community 194 Foster Street Boston MA 02135 USA
# Yelp search failed for this location: Harvard University Harvard Law School 1557 Massachusetts Avenue Cambridge MA 02138 USA
# Yelp search failed for this location: Harvard Medical University Longwood Campus 240 Longwood Avenue Boston MA 02115 USA
# Yelp search failed for this location: Massachusetts Institute of Technology 232-286 Vassar Street Cambridge MA 02139 USA
# Yelp search failed for this location: Harvard Medical University Longwood Campus 665 Huntington Avenue Boston MA 02115 USA
# ...

# %%
map_yelp_outer2.head()
# Out:
#   business lat business lng  business name  error error-message  \
# 0     42.36622    -71.18232    Wonder Cafe  False          None
# 1     42.36995    -71.19131  Asiana Fusion  False          None
# 2     42.37562    -71.15648     Shangri-La  False          None
# 3     42.36622    -71.18232    Wonder Cafe  False          None
# 4     42.35033    -71.16899  New Hong Kong  False          None
#
#                           id        lat        lng oauth2-ascii-error  \
# 0      wonder-cafe-watertown  42.375032 -71.183853              False
# 1  asiana-fusion-watertown-2  42.375032 -71.183853              False
# 2         shangri-la-belmont  42.375032 -71.183853              False
# 3      wonder-cafe-watertown  42.352835 -71.183853              False
# 4     new-hong-kong-brighton  42.352835 -71.183853              False
#
#         px       py rating   search  seconds       score
# 0  1267800  1551100    3.5  chinese     1732  141.387755
# ...

# %%
map_yelp_outer = mapster.merge_map_yelp(map_yelp_outer,map_yelp_outer2)
map_yelp_outer.head()
# Out:
#   business lat business lng         business name  error error-message  \
# 0     42.36539    -71.18173  Wild Willy's Burgers  False          None
# 1     42.37002    -71.19366          Halfway Cafe  False          None
# 2     42.36584    -71.16578  Strip-T's Restaurant  False          None
# 0     42.36622    -71.18232           Wonder Cafe  False          None
# 1     42.36995    -71.19131         Asiana Fusion  False          None
#
#                           id        lat        lng oauth2-ascii-error  \
# 0                          0  42.375032 -71.183853              False
# 1                          1  42.375032 -71.183853              False
# 2                          2  42.375032 -71.183853              False
# 0      wonder-cafe-watertown  42.375032 -71.183853              False
# 1  asiana-fusion-watertown-2  42.375032 -71.183853              False
#
#         px       py rating   search  seconds       score
# 0  1267800  1551100    3.5   burger     1177   96.081633
# ...

# %%
map_yelp_outer.tail()
# Out:
#      business lat business lng                                 business name  \
# 3550     42.31436    -71.10414  Bella Luna Restaurant & The Milky Way Lounge
# 3551     42.30598    -71.08035                                   Burger King
# 3549     42.31522     -71.0988               Lucky Boston Chinese Restaurant
# 3550      42.3058    -71.10781                                    JP Kitchen
# 3551     42.30992    -71.11546                           Kamado Super Fusion
#
#       error error-message                                       id        lat  \
# 3550  False          None                                Unnamed 0  42.306832
# 3551  False          None                                Unnamed 1  42.306832
# 3549  False          None  lucky-boston-chinese-restaurant-roxbury  42.306832
# 3550  False          None                 jp-kitchen-jamaica-plain  42.306832
# 3551  False          None      kamado-super-fusion-jamaica-plain-2  42.306832
#
# ...

# %%
mapster.score_map_yelp(outer,map_yelp_outer)

# %%
outer.tail()
# Out:
#                                               address        lat        lng  \
# 1828  1285-1329 Tremont Street, Boston, MA 02120, USA  42.332217 -71.093731
# 1829   265-273 Roxbury Street, Roxbury, MA 02119, USA  42.330631 -71.093731
# 1830        26 Linwood Square, Roxbury, MA 02119, USA  42.329045 -71.093731
# 1831         117 Cedar Street, Roxbury, MA 02119, USA  42.327458 -71.093731
# 1842             Pierpont Road, Boston, MA 02121, USA  42.306832 -71.093731
#
#            px       py    tx    ty  zoom      burger     chinese
# 1828  1268850  1551775  4956  6061    14   71.428571  123.346939
# 1829  1268850  1551800  4956  6061    14   74.530612  112.244898
# 1830  1268850  1551825  4956  6061    14  102.367347   78.937500
# 1831  1268850  1551850  4956  6061    14   79.755102   83.346939
# 1842  1268850  1552175  4956  6063    14   82.612245   56.812500

# %%
outer.to_pickle('./pickles/outside_watertown_jamaica_plain.pkl')
map_yelp_outer.to_pickle('./pickles/map_yelp_outside_watertown_jamaica_plain.pkl')

# %% [markdown]
# # 4/20/2015

# %%
outer = pd.read_pickle('./pickles/outside_watertown_jamaica_plain.pkl')
map_yelp_outer = pd.read_pickle('./pickles/map_yelp_outside_watertown_jamaica_plain.pkl')

# %%
map_yelp_outer2 = mapster.map_yelp(outer,'mexican')
# Out:
# Yelp search failed for this location: Boston College Boston College - Brighton Campus 9 Lake Street Boston MA 02135 USA
# Yelp search failed for this location: Boston College Boston College - Brighton Campus 2119-2163 Highway 30 Boston MA 02135 USA
# Yelp search failed for this location: Boston College Boston College - Brighton Campus Blessed Peter Faber Jesuit Community 194 Foster Street Boston MA 02135 USA
# Yelp search failed for this location: Harvard University Harvard Law School 1557 Massachusetts Avenue Cambridge MA 02138 USA
# Yelp search failed for this location: Harvard Medical University Longwood Campus 240 Longwood Avenue Boston MA 02115 USA
# Yelp search failed for this location: Massachusetts Institute of Technology 232-286 Vassar Street Cambridge MA 02139 USA
# Yelp search failed for this location: Harvard Medical University Longwood Campus 665 Huntington Avenue Boston MA 02115 USA
# ...

# %%
map

# %%
map_yelp_outer2.tail()
# Out:
#      business lat business lng      business name  error error-message  \
# 3547     42.32263    -71.10325  Latino Restaurant  False          None
# 3548     42.33861    -71.07604          El Centro  False          None
# 3549     42.31161    -71.08102         La Cuchara  False          None
# 3550     42.30914    -71.10532       El Embajador  False          None
# 3551     42.31634    -71.10328   Amory Restaurant  False          None
#
#                                    id        lat        lng  \
# 3547  latino-restaurant-jamaica-plain  42.327458 -71.093731
# 3548                 el-centro-boston  42.327458 -71.093731
# 3549                la-cuchara-boston  42.306832 -71.093731
# 3550       el-embajador-jamaica-plain  42.306832 -71.093731
# 3551   amory-restaurant-jamaica-plain  42.306832 -71.093731
#
#      oauth2-ascii-error       px       py rating   search  seconds       score
# 3547              False  1268850  1551850      4  mexican     1092   68.250000
# ...

# %% [markdown]
# # ran out of keys, need to fill in map_yelp_outer2...
